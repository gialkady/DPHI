# %%
import pandas as pd

# %%
ckd_data = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Chronic%20Kidney%20Disease%20(CKD)%20Dataset/ChronicKidneyDisease.csv")

# %%
#ckd_data.head(10) & ckd_data.tail(7)
#ckd_data.head(9) & ckd_data.tail(6)
ckd_data.head(11) & ckd_data.tail(8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     264         #  (xint or xbool) and (yint or bool)
# --> 265         result = op(x, y)
#     266     except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-88636f77703a> in <module>
#       1 #ckd_data.head(10) & ckd_data.tail(7)
#       2 #ckd_data.head(9) & ckd_data.tail(6)
# ----> 3 ckd_data.head(11) & ckd_data.tail(8)
#       4
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ...

# %%
ckd_data.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %% [markdown]
# - int = 1
# - float = 11
# - object = 14

# %%
ckd_data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
ckd_data.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
ckd_data.classification.describe()
# Out:
# count     400
# unique      3
# top       ckd
# freq      248
# Name: classification, dtype: object

# %%
ckd_data.loc[247:253, ["id", "age", "classification"]]
# Out:
#       id   age classification
# 247  247  54.0            ckd
# 248  248  59.0            ckd
# 249  249  56.0            ckd
# 250  250  40.0         notckd
# 251  251  23.0         notckd
# 252  252  45.0         notckd
# 253  253  57.0         notckd

# %%
ckd_data.age.describe()
# Out:
# count    391.000000
# mean      51.483376
# std       17.169714
# min        2.000000
# 25%       42.000000
# 50%       55.000000
# 75%       64.500000
# max       90.000000
# Name: age, dtype: float64

# %%
ckd_data.rename(columns = {
   "id": "Id",
   "age": "Age",
   "bp": "blood_pressure",
}, inplace=True)

# %%
ckd_data.head()
# Out:
#    Id   Age  blood_pressure     sg   al   su     rbc        pc         pcc  \
# 0   0  48.0            80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1   1   7.0            50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2   2  62.0            80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3   3  48.0            70.0  1.005  4.0  0.0  normal  abnormal     present
# 4   4  51.0            80.0  1.010  2.0  0.0  normal    normal  notpresent
#
#            ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2  notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3  notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4  notpresent  ...   35  7300  4.6   no   no   no  good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# 4            ckd
#
# ...

# %%
ckd_data.isnull().sum()
# Out:
# Id                  0
# Age                 9
# blood_pressure     12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
ckd_data ['blood_pressure'].median()
# Out:
# 80.0

# %%
ckd_data ['blood_pressure'].fillna(ckd_data ['blood_pressure'].median(), inplace=True)

# %%
ckd_data.head()
# Out:
#    Id   Age  blood_pressure     sg   al   su     rbc        pc         pcc  \
# 0   0  48.0            80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1   1   7.0            50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2   2  62.0            80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3   3  48.0            70.0  1.005  4.0  0.0  normal  abnormal     present
# 4   4  51.0            80.0  1.010  2.0  0.0  normal    normal  notpresent
#
#            ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0  notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# 1  notpresent  ...   38  6000  NaN   no   no   no  good   no   no
# 2  notpresent  ...   31  7500  NaN   no  yes   no  poor   no  yes
# 3  notpresent  ...   32  6700  3.9  yes   no   no  poor  yes  yes
# 4  notpresent  ...   35  7300  4.6   no   no   no  good   no   no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3            ckd
# 4            ckd
#
# ...

# %%
ckd_data.describe()
# Out:
#                Id         Age  blood_pressure          sg          al  \
# count  400.000000  391.000000      400.000000  353.000000  354.000000
# mean   199.500000   51.483376       76.575000    1.017408    1.016949
# std    115.614301   17.169714       13.489785    0.005717    1.352679
# min      0.000000    2.000000       50.000000    1.005000    0.000000
# 25%     99.750000   42.000000       70.000000    1.010000    0.000000
# 50%    199.500000   55.000000       80.000000    1.020000    0.000000
# 75%    299.250000   64.500000       80.000000    1.020000    2.000000
# max    399.000000   90.000000      180.000000    1.025000    5.000000
#
#                su         bgr          bu          sc         sod         pot  \
# count  351.000000  356.000000  381.000000  383.000000  313.000000  312.000000
# mean     0.450142  148.036517   57.425722    3.072454  137.528754    4.627244
# std      1.099191   79.281714   50.503006    5.741126   10.408752    3.193904
# ...

# %%
ckd_data.cad
# Out:
# 0      no
# 1      no
# 2      no
# 3      no
# 4      no
#        ..
# 395    no
# 396    no
# 397    no
# 398    no
# 399    no
# Name: cad, Length: 400, dtype: object

# %%
ckd_data.cad.describe()
# Out:
# count     398
# unique      3
# top        no
# freq      362
# Name: cad, dtype: object

# %%
ckd_data.cad.isnull().sum()
# Out:
# 2

# %%
ckd_data.cad.describe() #categorical
# Out:
# count     398
# unique      3
# top        no
# freq      362
# Name: cad, dtype: object

# %%
ckd_data.to_csv("test.csv", index=True)

# %%
ckd_data.to_csv("test.csv")
